# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool=TavilySearchResults(max_results=2)
res=tool.invoke({"query":'future of ai agent in india'})
res
# Out:
# [{'title': 'AI Agent Development Company in India 2026 | Custom AI Agent Services',
#   'url': 'https://vegavid.com/in/ai-agent-development-company',
# ...
